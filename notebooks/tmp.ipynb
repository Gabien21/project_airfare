# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/raw/flight_prices_SGN_to_HAN.csv")
df
# Out:
#         Departure Location     Departure Time Arrival Location  \
# 0     TP Hồ Chí Minh (SGN)  23:05, 01/04/2025     Hà Nội (HAN)
# 1     TP Hồ Chí Minh (SGN)  05:10, 01/04/2025     Hà Nội (HAN)
# 2     TP Hồ Chí Minh (SGN)  18:45, 01/04/2025     Hà Nội (HAN)
# 3     TP Hồ Chí Minh (SGN)  20:00, 01/04/2025     Hà Nội (HAN)
# 4     TP Hồ Chí Minh (SGN)  20:05, 01/04/2025     Hà Nội (HAN)
# ...                    ...                ...              ...
# 7529  TP Hồ Chí Minh (SGN)  19:35, 30/06/2025     Hà Nội (HAN)
# 7530  TP Hồ Chí Minh (SGN)  20:00, 30/06/2025     Hà Nội (HAN)
# 7531  TP Hồ Chí Minh (SGN)  16:40, 30/06/2025     Hà Nội (HAN)
# 7532  TP Hồ Chí Minh (SGN)  18:00, 30/06/2025     Hà Nội (HAN)
# 7533  TP Hồ Chí Minh (SGN)  10:00, 30/06/2025     Hà Nội (HAN)
#
#            Arrival Time Flight Duration              Aircraft Type  \
# 0     01:15, 02/04/2025   2 giờ 10 phút       Máy bay: Airbus A321
# 1     07:20, 01/04/2025   2 giờ 10 phút       Máy bay: Airbus A321
# ...

# %%
df['Ticket Price'].apply(lambda r: r.split("Chuyến bay")[0].strip()).value_counts()
# Out:
# Ticket Price
# Vietnam Airlines      3923
# Vietjet Air           2488
# Bamboo Airways         850
# Pacific Airlines       182
# Vietravel Airlines      91
# Name: count, dtype: int64
